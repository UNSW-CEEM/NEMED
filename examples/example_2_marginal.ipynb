# %% [markdown]
# ## NEM Emissions Data tool
# ### Example Two: Marginal Emitter
# Using the package to retrieve the marginal emitter for a historical period in the NEM

# %% [markdown]
# #### Import Packages

# %%
from nemed.process import *

# %% [markdown]
# #### Define Local Parameters

# %%
cache = "" # Change this to a existing local empty folder or leave blank "" to create new cache
start_year = 2021
start_month = 1
start_day = 1
end_year = 2021
end_month = 2
end_day = 28

# %% [markdown]
# #### Get the Marginal Emitter for each Dispatch Interval

# %%
get_marginal_emitter(cache, start_year, start_month, start_day, end_year, end_month, end_day, redownload_xml=False)
# Out:
# Retrieving static table Generators and Scheduled Loads.
# No existing JSON found for date 2021-02-28 00:00:00
# Redownloading XML data
# ...
# Converting 21024 XML files to JSON
# Reading JSON to pandas Dataframe
#                     RegionID            DUID Dispatch Type  \
# PeriodID
# 2019-01-30 04:05:00     NSW1        TARONG#1     Generator
# 2019-01-30 04:05:00     NSW1        TARONG#4     Generator
# 2019-01-30 04:05:00     NSW1        TARONG#3     Generator
# 2019-01-30 04:05:00     NSW1        TARONG#2     Generator
# 2019-01-30 04:05:00     QLD1        TARONG#1     Generator
# ...                      ...             ...           ...
# 2021-02-28 04:00:00      SA1          TORRB1     Generator
# 2021-02-28 04:00:00      SA1          TORRB4     Generator
# 2021-02-28 04:00:00     TAS1             MP2     Generator
# 2021-02-28 04:00:00     TAS1  T-V-MNSP1,TAS1           NaN
# 2021-02-28 04:00:00     VIC1             MP2     Generator
#
# ...
